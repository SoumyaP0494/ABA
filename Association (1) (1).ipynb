# %%
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
ap = pd.DataFrame.from_csv('MSFT.csv')
ap.drop(["PriceDiff"], axis = 1, inplace = True)
ap_data = ap.loc['2015-01-01':'2019-12-31']
ap_data.head()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  41.979183  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  41.593143  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  40.982681  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  41.503380  29114100
# 2015-01-08  46.750000  47.750000  46.720001  47.590000  42.724323  29645200

# %%
ap_data.cov()
# Out:
#                    Open          High           Low         Close  \
# Open       1.028696e+03  1.034718e+03  1.019029e+03  1.027339e+03
# High       1.034718e+03  1.041150e+03  1.025135e+03  1.033769e+03
# Low        1.019029e+03  1.025135e+03  1.010044e+03  1.018271e+03
# Close      1.027339e+03  1.033769e+03  1.018271e+03  1.026962e+03
# Adj Close  1.064285e+03  1.070932e+03  1.054877e+03  1.063870e+03
# Volume    -9.305070e+07 -9.124491e+07 -9.626441e+07 -9.456881e+07
#
#               Adj Close        Volume
# Open       1.064285e+03 -9.305070e+07
# High       1.070932e+03 -9.124491e+07
# Low        1.054877e+03 -9.626441e+07
# Close      1.063870e+03 -9.456881e+07
# Adj Close  1.102215e+03 -9.840497e+07
# Volume    -9.840497e+07  1.949390e+14

# %%
ap_data.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999820  0.999708  0.999524   0.999497 -0.207791
# High       0.999820  1.000000  0.999664  0.999746   0.999705 -0.202536
# Low        0.999708  0.999664  1.000000  0.999806   0.999766 -0.216943
# Close      0.999524  0.999746  0.999806  1.000000   0.999950 -0.211359
# Adj Close  0.999497  0.999705  0.999766  0.999950   1.000000 -0.212292
# Volume    -0.207791 -0.202536 -0.216943 -0.211359  -0.212292  1.000000

# %%
corrMatrix = ap_data.corr()
sn.heatmap(corrMatrix, annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from pandas.plotting import scatter_matrix
sm = scatter_matrix(ap_data, figsize=(10, 10))

# %%
ap.plot(kind='scatter', x='Volume', y='Close', figsize=(10, 10))

# %%
#We shall base on the association between Volume and Close and create a simple linear regression model. 
#Let's use python in estimating the values of B0 and B1 (intercept and slope)
